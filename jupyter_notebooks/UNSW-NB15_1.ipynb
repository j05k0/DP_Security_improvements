# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
features = pd.read_csv('../datasets/UNSW-NB15_features.csv')
names = np.array(features['Name'])
names
# Out:
# array(['srcip', 'sport', 'dstip', 'dsport', 'proto', 'state', 'dur',
#        'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service',
#        'Sload', 'Dload', 'Spkts', 'Dpkts', 'swin', 'dwin', 'stcpb',
#        'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len',
#        'Sjit', 'Djit', 'Stime', 'Ltime', 'Sintpkt', 'Dintpkt', 'tcprtt',
#        'synack', 'ackdat', 'is_sm_ips_ports', 'ct_state_ttl',
#        'ct_flw_http_mthd', 'is_ftp_login', 'ct_ftp_cmd', 'ct_srv_src',
#        'ct_srv_dst', 'ct_dst_ltm', 'ct_src_ ltm', 'ct_src_dport_ltm',
#        'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label'],
#       dtype=object)

# %%
data = pd.read_csv('../datasets/UNSW-NB15_1.csv', names=names)
data.head()
# Out:
#         srcip  sport          dstip dsport proto state       dur  sbytes  \
# 0  59.166.0.0   1390  149.171.126.6     53   udp   CON  0.001055     132
# 1  59.166.0.0  33661  149.171.126.9   1024   udp   CON  0.036133     528
# 2  59.166.0.6   1464  149.171.126.7     53   udp   CON  0.001119     146
# 3  59.166.0.5   3593  149.171.126.5     53   udp   CON  0.001209     132
# 4  59.166.0.3  49664  149.171.126.0     53   udp   CON  0.001169     146
#
#    dbytes  sttl  ...    ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     164    31  ...             0           3           7          1
# 1     304    31  ...             0           2           4          2
# 2     178    31  ...             0          12           8          1
# 3     164    31  ...             0           6           9          1
# 4     178    31  ...             0           7           9          1
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
data.loc[data['sport'] == 3231].head(1)
# Out:
#           srcip sport          dstip dsport proto state       dur  sbytes  \
# 320  59.166.0.0  3231  149.171.126.5     80   tcp   FIN  28.78933    1052
#
#      dbytes  sttl  ...    ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 320     824    31  ...             0           6           4         10
#
#      ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 320            7                 6                 1               2
#
#      attack_cat  Label
# 320         NaN      0
#
# [1 rows x 49 columns]
